# %% [markdown]
# ## EXERCISES

# %% [markdown]
# #### Exercise 1

# %% [markdown]
# Write a program to read through a file and print the contents of the file (line by line) all in upper case.
#
# from [PEW] E8-1

# %%
f = open('/content/drive/MyDrive/Colab Notebooks/Workbook_2/exercise1 file.txt', 'r')
for line in f:
  line = line.strip().upper()
  print(line)
# Out:
# NETHAN QUINN JAEL
# BSCS 2 A
# ICT 110
# APP DEVELOPMENT AND EMERGING TECHNOLOGIES

# %% [markdown]
# #### Exercise 2

# %% [markdown]
# Write a program to read through a file and output the number of lines in a file.
#
# adapted from [PEW]

# %%
f = open('/content/drive/MyDrive/Colab Notebooks/Workbook_2/exercise1 file.txt', 'r')
lines = 0
for line in f:
  lines += 1
print(lines)
# Out:
# 4

# %% [markdown]
# ## CHALLENGE
#
# from [PEW] E8-2

# %% [markdown]
# Write a program to prompt for a file name, and then read through the file and look for lines of the form:

# %% [raw]
# X-DSPAM-Confidence: 0.8475

# %% [markdown]
# When you encounter a line that starts with "X-DSPAM-Confidence:" pull apart the line to extract the floating-point number on the line. Count these lines and then compute the total of the spam confidence values from these lines. When you reach the end of the file, print out the average spam confidence.

# %% [raw]
# Enter the file name: mbox.txt
# Average spam confidence: 0.894128046745
#
# Enter the file name: mbox-short.txt
# Average spam confidence: 0.750718518519

# %%
while True:
  f_name = input("Enter the file name: ")

  if (f_name.lower() == "exit"):
    break
  try:
    f = open('./{}'.format(f_name), 'r')

    sum_spam_confidence = 0
    n_line = 0
    for line in f:
      line = line.strip()

      if line.startswith("X-DSPAM-Confidence:"):
        spam_confidence = float(line[len("X-DSPAM-Confidence:"):])
        sum_spam_confidence += spam_confidence
        n_line += 1

    if (n_line != 0):
      print("Average spam confidence: {}".format(sum_spam_confidence/n_line))
    else:
      print("Spam confidence cannot be found")

  except Exception as e:
    print("File not found")
    continue
# Out:
# Enter the file name: F
# File not found
# Enter the file name: exit
